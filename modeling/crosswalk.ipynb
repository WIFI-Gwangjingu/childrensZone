# %%
import pandas
from google.colab import files

# %%
f = files.upload()
# Out:
#      <input type="file" id="files-2863985e-eb58-4002-b934-6a838a5a5b18" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2863985e-eb58-4002-b934-6a838a5a5b18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pandas.read_csv("서울시대로변횡단보도위치정보.csv", encoding="euc-kr")

data = data.loc[:, ["노드링크 유형", "노드 WKT", "링크 WKT", "시군구명", "읍면동명"]]
data["좌표"] = 0

for i, d in enumerate(data["노드 WKT"]):
  if(type(d) == str):
    data["좌표"][i] = d[6:-1]
  
for i, d in enumerate(data["링크 WKT"]):
  if(type(d) == str):
    data["좌표"][i] = d[11:-1]

data = data.drop(["노드 WKT", "링크 WKT"], axis = 1)
# Out:
# <ipython-input-8-e1393d7db171>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["좌표"][i] = d[6:-1]

# %%
data.to_csv("result.csv", encoding="euc-kr")
files.download("result.csv")

data
# Out:
#       노드링크 유형 시군구명   읍면동명                                                 좌표
# 0        LINK  종로구    부암동  126.9657085816752 37.59262760480967,126.965646...
# 1        LINK  종로구    창신동  127.01248914183903 37.57002641024621,127.01250...
# 2        LINK  종로구    필운동  126.96929248902234 37.575432558616114,126.9691...
# 3        LINK  종로구    장사동  126.99458763438037 37.56871226431096,126.99459...
# 4        LINK  종로구  태평로1가  126.9774587328279 37.569336587353035,126.97745...
# ...       ...  ...    ...                                                ...
# 31075    NODE  강동구    암사동                 127.12471471434853 37.553724686418
# 31076    NODE  강동구    강일동              127.18139987438292 37.561833536663066
# 31077    NODE  강동구    암사동               127.12464863826722 37.55374764152453
# 31078    NODE  강동구    성내동               127.1221315885429 37.527957872676545
# 31079    NODE  강동구    성내동               127.12253412788506 37.52877126768239
#
# [31080 rows x 4 columns]

# %%
import pandas as pd

# %%
data = pd.read_csv("../기존 입지 분석 이용 데이터/횡단보도 중앙값.csv", encoding = 'cp949')
data.head()
# Out:
#    Unnamed: 0 노드링크 유형 시군구명   읍면동명  \
# 0           0    LINK  종로구    부암동
# 1           1    LINK  종로구    창신동
# 2           2    LINK  종로구    필운동
# 3           3    LINK  종로구    장사동
# 4           4    LINK  종로구  태평로1가
#
#                                                   좌표
# 0  126.9657085816752 37.59262760480967,126.965646...
# 1  127.01248914183903 37.57002641024621,127.01250...
# 2  126.96929248902234 37.575432558616114,126.9691...
# 3  126.99458763438037 37.56871226431096,126.99459...
# 4  126.9774587328279 37.569336587353035,126.97745...

# %%
data = data.drop(labels = 'Unnamed: 0', axis = 1)

# %%
nw = data[data['시군구명']=='노원구']
nw
# Out:
#       노드링크 유형 시군구명 읍면동명                                                 좌표
# 10265    NODE  노원구  상계동               127.05118315540707 37.67092655265278
# 10266    NODE  노원구  상계동              127.06204978044761 37.648808922707765
# 10267    LINK  노원구  상계동  127.06050729566218 37.655846808751924,127.0605...
# 10268    NODE  노원구  상계동                 127.062394847334 37.64890246177679
# 10269    LINK  노원구  하계동  127.06601851622946 37.63442878046994,127.06594...
# ...       ...  ...  ...                                                ...
# 11425    NODE  노원구  중계동              127.06824538260295 37.641621111236134
# 11426    LINK  노원구  월계동  127.06813465938924 37.62378717355994,127.06841...
# 11427    LINK  노원구  중계동  127.0656428795852 37.64123432369986,127.066016...
# 11428    NODE  노원구  상계동              127.06034622542055 37.654416065912955
# 11429    LINK  노원구  중계동  127.07492705858591 37.65802856919646,127.07528...
#
# [1165 rows x 4 columns]

# %%
gn = data[data['시군구명']=='강남구']
gn
# Out:
#       노드링크 유형 시군구명  읍면동명                                                 좌표
# 25412    LINK  강남구   역삼동  127.04260922925265 37.502282824076026,127.0423...
# 25413    NODE  강남구   도곡동               127.05296109655878 37.48634860944576
# 25414    NODE  강남구   도곡동              127.05266515854537 37.486167945441835
# 25415    NODE  강남구   도곡동               127.05383024400355 37.48888165268211
# 25416    NODE  강남구   삼성동                127.0607333539185 37.51410956560504
# ...       ...  ...   ...                                                ...
# 27469    NODE  강남구   신사동               127.04030205055834 37.52775346859122
# 27470    NODE  강남구  압구정동              127.04066716774349 37.528080605305185
# 27471    NODE  강남구   개포동                127.07340385801524 37.4877721982039
# 27472    LINK  강남구   도곡동  127.05554500691605 37.488113047147,127.0554732...
# 27473    NODE  강남구   논현동               127.03065647967827 37.51372094327945
#
# [2062 rows x 4 columns]

# %%
location = gn.loc[0,'좌표']
location
# Out:
# '127.04260922925265 37.502282824076026,127.04236823785438 37.502820721040784'

# %%
c = location.find(',') 
lo1 = location[:c]

b = lo1.find(' ')
lat1 = float(lo1[b+1:])
long1 = float(lo1[:b])

print(lat1, long1)
# Out:
# 37.502282824076026 127.04260922925265

# %%
'Latitude' : '위도' 3~, 'Longitude' : '경도'127~

# %%
location = gn.loc[0,'좌표']
c = location.find(',') 
lo1 = location[:c]
b = lo1.find(' ')
위도 = float(lo1[b+1:])
경도 = float(lo1[:b])

print(위도, 경도)
# Out:
# 37.502282824076026 127.04260922925265

# %%
for i in range(len(gn)):
    location = gn.loc[0,'좌표']
    if (location.find(',') >0):
        c = location.find(',') 
        lo1 = location[:c]
        b = lo1.find(' ')
        gn['위도'] = float(lo1[b+1:])
        gn['경도'] = float(lo1[:b])
    else :
        b = location.find(' ')
        gn['위도'] = float(location[b+1:])
        gn['경도'] = float(location[:b])

# %%
gn
# Out:
#      노드링크 유형 시군구명  읍면동명                                                 좌표  \
# 0       LINK  강남구   역삼동  127.04260922925265 37.502282824076026,127.0423...
# 1       NODE  강남구   도곡동               127.05296109655878 37.48634860944576
# 2       NODE  강남구   도곡동              127.05266515854537 37.486167945441835
# 3       NODE  강남구   도곡동               127.05383024400355 37.48888165268211
# 4       NODE  강남구   삼성동                127.0607333539185 37.51410956560504
# ...      ...  ...   ...                                                ...
# 2057    NODE  강남구   신사동               127.04030205055834 37.52775346859122
# 2058    NODE  강남구  압구정동              127.04066716774349 37.528080605305185
# 2059    NODE  강남구   개포동                127.07340385801524 37.4877721982039
# 2060    LINK  강남구   도곡동  127.05554500691605 37.488113047147,127.0554732...
# 2061    NODE  강남구   논현동               127.03065647967827 37.51372094327945
#
#              위도          경도
# 0     37.502283  127.042609
# ...

# %%
gn
# Out:
#       노드링크 유형 시군구명  읍면동명                                                 좌표  \
# 25412    LINK  강남구   역삼동  127.04260922925265 37.502282824076026,127.0423...
# 25413    NODE  강남구   도곡동               127.05296109655878 37.48634860944576
# 25414    NODE  강남구   도곡동              127.05266515854537 37.486167945441835
# 25415    NODE  강남구   도곡동               127.05383024400355 37.48888165268211
# 25416    NODE  강남구   삼성동                127.0607333539185 37.51410956560504
# ...       ...  ...   ...                                                ...
# 27469    NODE  강남구   신사동               127.04030205055834 37.52775346859122
# 27470    NODE  강남구  압구정동              127.04066716774349 37.528080605305185
# 27471    NODE  강남구   개포동                127.07340385801524 37.4877721982039
# 27472    LINK  강남구   도곡동  127.05554500691605 37.488113047147,127.0554732...
# 27473    NODE  강남구   논현동               127.03065647967827 37.51372094327945
#
#               위도          경도
# ...
